# %%
import requests
import pygal

# %%
from pygal.style import LightColorizedStyle as LCS, LightenStyle as LS

# %%
url = 'https://api.github.com/search/repositories?q=machine+learning&sort=stars'

# %%
r = requests.get(url)

# %%
print("Status code:", r.status_code)
# Out:
# Status code: 200

# %%
response_dict = r.json()

# %%
print("Total repositories:", response_dict['total_count'])
# Out:
# Total repositories: 183446

# %%
repo_dicts = response_dict['items']

# %%
names, stars = [], []

# %%
for repo_dict in repo_dicts:
    names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

# %%
my_style = LS('#333366', base_style=LCS)

# %%
chart = pygal.Bar(style=my_style, x_label_rotation=45, show_legend=False)

# %%
chart.x_labels = names

# %%
chart.add('',stars)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\program files\python3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# d:\program files\python3\lib\site-packages\pygal\graph\base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# d:\program files\python3\lib\site-packages\pygal\graph\public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
chart.title('Most-Starred Repositories')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-15f90c84d94c> in <module>
# ----> 1 chart.title('Most-Starred Repositories')
#
# d:\program files\python3\lib\site-packages\pygal\graph\base.py in __getattribute__(self, name)
#      71                 self, 'state', None
#      72         ) is None or name not in self.state.__dict__:
# ---> 73             return super(BaseGraph, self).__getattribute__(name)
#      74         return getattr(self.state, name)
#      75
#
# AttributeError: 'Bar' object has no attribute 'title'

# %%
chart.render_to_file('python_repos.svg')
